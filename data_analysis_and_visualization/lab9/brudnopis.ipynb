# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings('ignore')

# %%
pl_ts = pd.read_csv('./poland_timeseries.csv')
ua_ts = pd.read_csv('./ukraine_timeseries.csv')
